# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataset\Advertising_Budget_and_Sales-1.csv')
df.head(10)
# Out:
#    Unnamed: 0  TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)  \
# 0           1             230.1                 37.8                     69.2
# 1           2              44.5                 39.3                     45.1
# 2           3              17.2                 45.9                     69.3
# 3           4             151.5                 41.3                     58.5
# 4           5             180.8                 10.8                     58.4
# 5           6               8.7                 48.9                     75.0
# 6           7              57.5                 32.8                     23.5
# 7           8             120.2                 19.6                     11.6
# 8           9               8.6                  2.1                      1.0
# 9          10             199.8                  2.6                     21.2
#
#    Sales ($)
# 0       22.1
# 1       10.4
# 2        9.3
# 3       18.5
# 4       12.9
# 5        7.2
# 6       11.8
# 7       13.2
# 8        4.8
# 9       10.6

# %%
df = df.drop(["Unnamed: 0"], axis=1)
df.head()
# Out:
#    TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)  Sales ($)
# 0             230.1                 37.8                     69.2       22.1
# 1              44.5                 39.3                     45.1       10.4
# 2              17.2                 45.9                     69.3        9.3
# 3             151.5                 41.3                     58.5       18.5
# 4             180.8                 10.8                     58.4       12.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   TV Ad Budget ($)         200 non-null    float64
#  1   Radio Ad Budget ($)      200 non-null    float64
#  2   Newspaper Ad Budget ($)  200 non-null    float64
#  3   Sales ($)                200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.columns = ['TV','Radio','Newspaper','Sales']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
print(df.shape)
# Out:
# (200, 4)

# %%
categorical = df.select_dtypes(include="object")
categorical.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.describe().T
# Out:
#            count      mean        std  min     25%     50%      75%    max
# TV         200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4
# Radio      200.0   23.2640  14.846809  0.0   9.975   22.90   36.525   49.6
# Newspaper  200.0   30.5540  21.778621  0.3  12.750   25.75   45.100  114.0
# Sales      200.0   14.0225   5.217457  1.6  10.375   12.90   17.400   27.0

# %% [markdown]
# (B). EXPLORATORY DATA ANALYSIS

# %%
for col in df.columns:
    plt.figure(figsize=(10, 5))
    sns.histplot(data=df[col], bins=40, kde=True)
    plt.title(f"{col.upper()} Distribution")
    plt.show()

# %%
for col in df.columns:
    plt.figure(figsize=(6, 4))
    sns.violinplot(y=df[col], color="skyblue")
    plt.title(f"{col.upper()} Distribution")
    plt.xticks([])
    plt.tight_layout()
    plt.show()

# %%
for col in df.columns:
    plt.figure(figsize=(6, 8))
    sns.boxplot(data=df, y=col, color="skyblue")
    plt.title(f"{col.upper()} Spread")
    plt.show()

# %%
means = df.mean(numeric_only=True)

plt.figure(figsize=(8,5))
means.plot(kind='bar', color='skyblue')
plt.title('Mean Values of Each Feature')
plt.ylabel('Mean')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha = 0.7)
plt.tight_layout()
plt.show()

# %%
total = df.sum(numeric_only=True)

plt.figure(figsize=(8,5))
total.plot(kind='bar', color='skyblue')
plt.title('Total Values of Each Feature')
plt.ylabel('Total sum')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--' , alpha=0.7)
plt.tight_layout()
plt.show()

# %%
for col in df.columns:
    plt.figure(figsize=(8,6))
    sns.scatterplot(data=df, x='Sales', y=col)
    plt.title(f'scatter plot of Sales vs. {col.upper()}')
    plt.show()

# %%
corr_matrix = df.corr()
plt.figure(figsize=(10,6))
sns.heatmap(corr_matrix, annot=True, cmap='Blues')
plt.title('Correlation Heatmap')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
corr_matrix= df.corr()
plt.figure(figsize=(10,6))
sns.heatmap(corr_matrix, annot=False, cmap='Blues')
plt.title('Correlation Heatmap')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
mask= np.triu(np.ones_like(corr_matrix),k=1)
plt.figure(figsize=(10,8))
sns.heatmap(
    corr_matrix,
    annot=True,
    cmap='coolwarm',
    vmin=-1,
    vmax=1,
    center=0,
    mask=mask,
    cbar=False
    
)
plt.title('Correlation matrix (Lower Triangle)\n')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
mask = np.tril(np.ones_like(corr_matrix), k=-1)
plt.figure(figsize=(10, 6))
sns.heatmap(
    corr_matrix,
    annot=True,
    cmap="coolwarm",
    vmin=-1,
    vmax=1,
    center=0,
    mask=mask,
    cbar=True,
)
plt.title('(Correlation Matrix (Upper Triangle)")')
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
g = sns.pairplot(data=df, 
             diag_kind="auto",
             kind="reg",
             palette='tab10',
             height=5
             )
# add grid to each inner plot
for ax in g.axes.flatten():
    if ax is not None:
        ax.grid(True, linestyle='--', alpha=0.1)
# add title and adjust layout
plt.suptitle('Pairwise Relationships by Segment', y=1.02)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# C:\Users\USER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# C:\Users\USER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# C:\Users\USER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)

# %%
for col in df.columns:
    sns.regplot(data=df, 
                x=col, y="Sales", 
                scatter=True, 
                fit_reg=True, 
                marker="o"
                )
    plt.title(f'Regplot of Sales vs {col}')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## SIDE TRACTION LEARN TO CREATE SINE GRAPH

# %%
x = np.arange(0.0, 12.5, 0.06)
y = np.sin(x)
plt.plot(x, y)
plt.title("THE SINE GRAPH")
plt.xlabel("Degrees")
plt.ylabel("sin (x)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### SIMPLE LINEAR REGRESSION from step 23

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df[['TV']]
# Out:
#         TV
# 0    230.1
# 1     44.5
# 2     17.2
# 3    151.5
# 4    180.8
# ..     ...
# 195   38.2
# 196   94.2
# 197  177.0
# 198  283.6
# 199  232.1
#
# [200 rows x 1 columns]

# %%
df['Sales']
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
# Separate independent variable (TV) and dependent variable (sales)
x= df[['TV']] # Independent variable (predictor)
y= df[['Sales']] # Dependent variable (target)

# %%
print(x.shape, y.shape)
# Out:
# (200, 1) (200, 1)

# %%
# !pip install sklearn
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000002113ADC2380>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/sklearn/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000002113ADC2680>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/sklearn/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000002113ADC28C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/sklearn/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000002113ADC2A70>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/sklearn/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000002113ADC2C20>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/sklearn/
# ERROR: Could not find a version that satisfies the requirement sklearn (from versions: none)
# ERROR: No matching distribution found for sklearn

# %%
from sklearn.model_selection import train_test_split as split

x_train, x_test, y_train, y_test = split(x,y, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 from sklearn.model_selection import train_test_split as split
#       3 x_train, x_test, y_train, y_test = split(x,y, random_state=42)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
print(x_train.shape, y_train.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 print(x_train.shape, y_train.shape)
#
# NameError: name 'x_train' is not defined
